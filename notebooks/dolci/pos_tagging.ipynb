# %% [markdown]
# # Testing spacy trf POS
#
# I want to test my pipeline addition, make sure it processes the pipe-joined strings correctly.
#
# Across the entire dataset,

# %%
from pathlib import Path
root = Path.cwd().parent.parent
data_dir = root / "data"
dolci_dir = data_dir / "dolci"
dolci_dataset = dolci_dir / "dolci_sft_500.parquet"
dolci_professions_file = dolci_dir / "dolci_sft_500_professions.parquet"
professions_file = data_dir / "occupations" / "select_professions.json"

# %%
ambiguous_professions = set({   # if these words are found, do POS tagging and ensure noun
    "author",
    "coach",
    "cook",
    "guard",
    "judge",
    "nurse",
    "pilot",
    "broker",
    "tutor",
    "minister",
    "advocate",
    })
